# %%
'''This script drives the data acquisition and storage'''
import time
import requests
import json
import urllib2
import echonestkeys as secret
from fuzzywuzzy import fuzz, process
import psycopg2
from scraper import artists_wikipedia
from scraper import putumayo_artists
url = 'https://www.putumayo.com/african-blues-9-7-15-9-13-15/'
artists = putumayo_artists(url, 5)
artists.keys()

def artists(y1, y2, pgs):
    #y1 - first year to scrape wikipedia
    #y2 - second year
    #pgs - putumayo pages
    
    artists = []
    
    for i in range(y1, y2+1, 1):
        artists = artists + artists_wikipedia(i)

    url = 'https://www.putumayo.com/african-blues-9-7-15-9-13-15/'
    artists = artists + putumayo_artists(url, pgs).keys()
    return set(artists)

echo_limit = 0
def rate_limiter():
    global echo_limit
    echo_limit += 1
    if echo_limit%355 == 0:
        time.sleep(63)
        
def rate_reset():
    global echo_limit
    echo_limit = 0

api_keys = secret.apikeys()

def api_generator():
    key = api_keys.pop(0)
    api_keys.append(key)
    time.sleep(1)
    return key


def get_json(url):
    response = requests.get(url)
    if response.status_code==200:
        return json.loads(response.text)
#     print 'Response code not 200 for %s' % url
    return None

def fuzzy_match(a, names):
    lower = unicode.lower
    strlower = str.lower
    if a == names[0]:
        return 0
    try:
        if strlower(a) == lower(names[0]):
            return 0
    except:
        if lower(a) == lower(names[0]):
            return 0
    best = max([(fuzz.ratio(a, n),n) for n in names])
    if best[0]>0.7:
        return names.index(best[1])
    else:
        return -1

def get_sp_artist(query):
    q = '+'.join(query.split()).strip()
    url = "https://api.spotify.com/v1/search?q=%s&type=artist" % q
    results = get_json(url)['artists']['items']
    if results != []:
        names = [r['name'] for  r in results]
        index = fuzzy_match(query, names)
        if index != -1:
            return results[index]
    return None


def get_ec_track(artistId, track):
    key = api_generator()
    url = 'http://developer.echonest.com/api/v4/song/search?api_key=%s&format=json&results=1\
&artist_id=spotify:artist:%s&title=%s&bucket=audio_summary&bucket=artist_location' % (key, artistId , track)
    rate_limiter()
    response = get_json(url)
    if response:
        response = response['response']
        status = response['status']['code']
        if status == 0:
            songs = response['songs']
            if songs!=[]:
                return songs[0]
    return None

def get_sp_topTracks(sp_artistId):
    url = 'https://api.spotify.com/v1/artists/%s/top-tracks?country=US' % sp_artistId
    response = get_json(url)
    if response:
        tracks = response['tracks']
        if tracks:
            return tracks
    return None


# create table artists(name text, sp_id text, ec_id text, genres text[], popularity integer, images text, latitude double precision, longitude double precision, location text);
# create table tracks(name text, sp_id text, ec_id text, duration integer, preview text, explicit bool);
# create table audiosummary(sp_trackId text, time_signature integer, energy double precision, liveness double precision, tempo double precision, speechiness double precision, acousticness double precision,
#                           danceability double precision, instrumentalness double precision, key integer, loudness double precision, valence double precision, mode integer);
import cPickle
az = cPickle.load(file('artistrip','rb'))

# %%
conn = psycopg2.connect("dbname='worldmusicexplorer' user='home'")
cur = conn.cursor()
rate_reset()

for a in az:
    artist = get_sp_artist(a)
    if artist:
        sp_artistId = artist['id']
        sp_artistName = artist['name']
        sp_artistGenres = artist['genres']
        sp_artistPopularity = artist['popularity']
        try:
            sp_artistImageLinks = artist['images'][0]['url']
        except:
            sp_artistImageLinks = None
        tracks = get_sp_topTracks(sp_artistId)
        if tracks:
            if len(tracks) >= 1:
                track = tracks[0]
                sp_trackId = track['id']
                sp_trackName = track['name']
                sp_trackPreview = track['preview_url']
                sp_trackExplicit = track['explicit']
                sp_trackDuration = track['duration_ms']
                q_trackName = '%20'.join(sp_trackName.split(' '))
                ec_track = get_ec_track(sp_artistId, q_trackName)
                if ec_track:
                    ec_trackId = ec_track['id']
                    
                    audsum = ec_track['audio_summary']
                    
                    timesig = audsum['time_signature']
                    energy = audsum['energy']
                    liveness = audsum['liveness']
                    tempo = audsum['tempo']
                    speechiness = audsum['speechiness']
                    acousticness = audsum['acousticness']
                    danceability = audsum['danceability']
                    instrumentalness = audsum['instrumentalness']
                    key = audsum['key']
                    loudness = audsum['loudness']
                    valence = audsum['valence']
                    mode = audsum['mode']
                    
                    ec_artistId = ec_track['artist_id']
                    
                    ec_artistLocation = ec_track['artist_location']
                    if ec_artistLocation != {}:
                        print '%s has made it' % sp_artistName
                        latitude = ec_artistLocation['latitude']
                        location = ec_artistLocation['location']
                        longitude = ec_artistLocation['longitude']
                        
                        SQL = """insert into artists(name, sp_id, ec_id, genres, popularity, images, 
                        latitude, longitude, location) values (%s, %s, %s, %s, %s, %s, %s, %s, %s)"""
                        data = (sp_artistName, sp_artistId, ec_artistId, sp_artistGenres, sp_artistPopularity, sp_artistImageLinks,
                        latitude, longitude, location)
                        cur.execute(SQL, data) 
                        cur.execute("COMMIT")
        
                        SQL = "insert into tracks(name, sp_id, ec_id, duration, preview, explicit) values (%s, %s, %s, %s, %s, %s);"
                        data = (sp_trackName, sp_trackId, ec_trackId, sp_trackDuration, sp_trackPreview, sp_trackExplicit)
                        cur.execute(SQL, data)
                        cur.execute("COMMIT")
                        
                        SQL = """insert into audiosummary(sp_trackId, time_signature, energy, liveness, tempo, speechiness, acousticness,
                        danceability, instrumentalness, key, loudness, valence, mode) values (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, 
                        # %s, %s)"""
                        data = (sp_trackId, timesig,energy,liveness,tempo,speechiness,acousticness,danceability,
                        instrumentalness,key,loudness,valence,mode)
                        cur.execute(SQL, data)
                        cur.execute("COMMIT")
# Out:
# Alexandra Burke has made it
# Rocket Juice & The Moon has made it
# Eliza Doolittle has made it
# Queens of the Stone Age has made it
# Dierks Bentley has made it
# Deerhunter has made it
# Prong has made it
# Dan Croll has made it
# Architects has made it
# K'NAAN has made it
# Iamamiwhoami has made it
# Mystery has made it
# Goldfrapp has made it
# Bullet For My Valentine has made it
# Big Time Rush has made it
# Jukebox The Ghost has made it
# Chris Tomlin has made it
# Sleaford Mods has made it
# Swans has made it
# a-ha has made it
# Burzum has made it
# Gary Allan has made it
# The Crystal Method has made it
# Spawn of possession has made it
# Delorean has made it
# Red Hot Chili Peppers has made it
# Mala Rodríguez has made it
# Zomboy has made it
# MercyMe has made it
# Sons Of Magdalene has made it
# deadmau5 has made it
# The Joy Formidable has made it
# For The Fallen Dreams has made it
# Forever The Sickest Kids has made it
# D.R.I. has made it
# Finger Eleven has made it
# Airbourne has made it
# PUP has made it
# Brody Dalle has made it
# Emilíana Torrini has made it
# I Am The Avalanche has made it
# Vista Chino has made it
# Goodie Mob has made it
# Disturbed has made it
# The Decemberists has made it
# Fifth Harmony has made it
# Kings of Leon has made it
# Lindsey Stirling has made it
# Milo Greene has made it
# Reba McEntire has made it
# Foals has made it
# Queen has made it
# Sirenia has made it
# HAIM has made it
# The Band Perry has made it
# Ciara has made it
# Honningbarna has made it
# Glenn Danzig has made it
# Avenged Sevenfold has made it
# Marina and the Diamonds has made it
# Say Anything has made it
# Lake Street Dive has made it
# Whitney Houston has made it
# Paradise Lost has made it
# The Head and the Heart has made it
# Lacuna Coil has made it
# Ricky Martin has made it
# Bobby McFerrin has made it
# Blind Guardian has made it
# Of Monsters and Men has made it
# Jamie Lynn Spears has made it
# ONE OK ROCK has made it
# The Birthday Massacre has made it
# Ivy Levan has made it
# TV On The Radio has made it
# Hands Like Houses has made it
# Paloma Faith has made it
# Markus Schulz has made it
# Ludacris has made it
# Scar The Martyr has made it
# Ashley Monroe has made it
# Kevin Seconds has made it
# Death Grips has made it
# Jake Bugg has made it
# Lit has made it
# Cannibal Corpse has made it
# Luke Bryan has made it
# Palma Violets has made it
# Little Mix has made it
# Daughtry has made it
# Phoenix has made it
# Gama Bomb has made it
# Chase & Status has made it
# Animals As Leaders has made it
# LP has made it
# Hildegunn Øiseth has made it
# Nelly Furtado has made it
# Jamie's Elsewhere has made it
# Rise Against has made it
# The Bright Light Social Hour has made it
# Kamelot has made it
# Oceans Ate Alaska has made it
# Toni Braxton has made it
# The Used has made it
# Richie Sambora has made it
# Neil Finn has made it
# Dionne Warwick has made it
# Mayer Hawthorne has made it
# Suicidal Tendencies has made it
# Demi Lovato has made it
# Eleanor Friedberger has made it
# Adama Yalomba has made it
# Beck has made it
# Pepe Deluxe has made it
# Titus Andronicus has made it
# Barbra Streisand has made it
# Scale The Summit has made it
# Geir Lysne has made it
# Ella Eyre has made it
# August Burns Red has made it
# Public Enemy has made it
# Avril Lavigne has made it
# The Stooges has made it
# Eric Church has made it
# Yann Tiersen has made it
# Sting has made it
# Puscifer has made it
# Anti-Flag has made it
# Veil Of Maya has made it
# Shakira has made it
# The Neighbourhood has made it
# Hugh Laurie has made it
# George Ezra has made it
# Nightwish has made it
# Afrissippi has made it
# Alice In Chains has made it
# Anathema has made it
# Blood Red Shoes has made it
# Royal Blood has made it
# Pearl Jam has made it
# Sub Focus has made it
# The 1975 has made it
# Angel Olsen has made it
# Coheed and Cambria has made it
# Shayne Ward has made it
# Tesla Boy has made it
# Hurt has made it
# letlive. has made it
# AFI has made it
# Helena Paparizou has made it
# Sarah Brightman has made it
# Jazmine Sullivan has made it
# Metric has made it
# French Montana has made it
# Gwen Stefani has made it
# A Silent Film has made it
# Sarah McLachlan has made it
# Die Antwoord has made it
# Between The Buried And Me has made it
# Katharine McPhee has made it
# The Killers has made it
# OFF! has made it
# Kayo Dot has made it
# Kaizers Orchestra has made it
# Tori Amos has made it
# Blitzen Trapper has made it
# Ella Henderson has made it
# Gang Of Four has made it
# Theory of a Deadman has made it
# The Menzingers has made it
# Draco Rosa has made it
# Zac Brown Band has made it
# The Dandy Warhols has made it
# All That Remains has made it
# Basement Jaxx has made it
# Toumast has made it
# Kasabian has made it
# Usher has made it
# Madonna has made it
# Delphic has made it
# Allo Darlin' has made it
# Kid Rock has made it
# The Jealous Sound has made it
# A$AP Rocky has made it
# Rixton has made it
# Röyksopp & Robyn has made it
# Stooshe has made it
# Thousand Foot Krutch has made it
# Five Finger Death Punch has made it
# Khia has made it
# Katie Kim has made it
# Melanie Martinez has made it
# Joel Plaskett Emergency has made it
# Animal Collective has made it
# Unknown Mortal Orchestra has made it
# The Ocean Blue has made it
# The Strypes has made it
# Logic has made it
# The Naked And Famous has made it
# Dustin Kensrue has made it
# Ludovico Einaudi has made it
# Melissa Etheridge has made it
# Tristan Prettyman has made it
# BoA has made it
# Emblem3 has made it
# Brad Paisley has made it
# AlunaGeorge has made it
# Neck Deep has made it
# Pop Evil has made it
# Yanni has made it
# Tom Vek has made it
# A Fine Frenzy has made it
# Elizaveta has made it
# Set It Off has made it
# Victor Démé has made it
# Jesse McCartney has made it
# Naughty Boy has made it
# Sonny Landreth has made it
# Trivium has made it
# Guy Sebastian has made it
# Little Big Town has made it
# Idina Menzel has made it
# MS MR has made it
# The Knife has made it
# Tricky has made it
# Jehro has made it
# Chromeo has made it
# KB has made it
# Laura Marling has made it
# The Reverb Junkie has made it
# Vusi Mahlasela has made it
# Streetlight Manifesto has made it
# The Temper Trap has made it
# Lamb of God has made it
# The Beach Boys has made it
# Boards of Canada has made it
# I See Stars has made it
# Meat Puppets has made it
# Phoenix Rising has made it
# Aesop Rock has made it
# Kid Ink has made it
# Jill Scott has made it
# Ben Marwood has made it
# Demon Hunter has made it
# The Tallest Man On Earth has made it
# Nada Surf has made it
# The Bunny The Bear has made it
# Orianthi has made it
# Municipal Waste has made it
# Minus The Bear has made it
# TVXQ! has made it
# Now, Now has made it
# Andreas Loven has made it
# zebrahead has made it
# Classified has made it
# Casper has made it
# Emmure has made it
# Opeth has made it
# Tame Impala has made it
# Devendra Banhart has made it
# She & Him has made it
# Arthur Beatrice has made it
# Caribou has made it
# David Broza has made it
# Jhene Aiko has made it
# Chelsea Grin has made it
# Glamour Of The Kill has made it
# The Wombats has made it
# Olly Murs has made it
# Zendaya has made it
# Evans The Death has made it
# WALK THE MOON has made it
# Veruca Salt has made it
# 2NE1 has made it
# Jean-Michel Jarre has made it
# Kendrick Lamar has made it
# The Hold Steady has made it
# Literature has made it
# The Pretty Reckless has made it
# Bad Religion has made it
# St. Vincent has made it
# Nas has made it
# Wolf Alice has made it
# Death Cab for Cutie has made it
# John Butler Trio has made it
# Calle 13 has made it
# E-40 has made it
# Pinch has made it
# Nana Mizuki has made it
# AC/DC has made it
# Judas Priest has made it
# Screaming Females has made it
# Kerli has made it
# Suicide Silence has made it
# Ariel Pink has made it
# Seth MacFarlane has made it
# Childish Gambino has made it
# Bush has made it
# Fitz and The Tantrums has made it
# Lil' Kim has made it
# Lionel Richie has made it
# The Devil Wears Prada has made it
# Pennywise has made it
# Conchita Wurst has made it
# Avantasia has made it
# Natalia Kills has made it
# The Courteeners has made it
# The Rocket Summer has made it
# Nightmares On Wax has made it
# In Flames has made it
# Collective Soul has made it
# Ladyhawke has made it
# Pretty Lights has made it
# Howie Day has made it
# Kylie Minogue has made it
# Ace Frehley has made it
# OK Go has made it
# Volbeat has made it
# Editors has made it
# Chris Robinson Brotherhood has made it
# Eagulls has made it
# W.A.S.P. has made it
# Bobby Womack has made it
# Unleash The Archers has made it
# New Kids On The Block has made it
# Freshlyground has made it
# Lukas Nelson and Promise of the Real has made it
# Alter Bridge has made it
# Lady Antebellum has made it
# Mercury Rev has made it
# They Might Be Giants has made it
# Shearwater has made it
# Brandon Flowers has made it
# Combichrist has made it
# KT Tunstall has made it
# Arch Enemy has made it
# Tom DeLonge has made it
# Emmelie de Forest has made it
# Northlane has made it
# Lorde has made it
# Prince has made it
# Soul Asylum has made it
# Arkells has made it
# Kwabs has made it
# Atlas Genius has made it
# Lacrimosa has made it
# Kidz Bop Kids has made it
# Halestorm has made it
# While She Sleeps has made it
# blessthefall has made it
# Alesso has made it
# Robin Thicke has made it
# Paradise Lost has made it
# Clutch has made it
# Blood On The Dance Floor has made it
# Best Coast has made it
# Tom Jones has made it
# Monster Magnet has made it
# Francesca Battistelli has made it
# Earl Sweatshirt has made it
# NERVO has made it
# Viet Cong has made it
# Birdy has made it
# John Coltrane has made it
# The Story So Far has made it
# Daft Punk has made it
# Juicy J has made it
# The New Mendicants has made it
# Mark Ronson has made it
# f(x) has made it
# Feed Me has made it
# Slaves has made it
# Trey Songz has made it
# The Flashbulb has made it
# MAGIC! has made it
# Ratatat has made it
# Four Year Strong has made it
# Fuck Buttons has made it
# Device has made it
# Frightened Rabbit has made it
# Mastodon has made it
# Jazzamor has made it
# Falling In Reverse has made it
# Heavenly Beat has made it
# The xx has made it
# SULK has made it
# Steven Wilson has made it
# Jamie Foxx has made it
# Ian Anderson has made it
# Ice Cube has made it
# Devin Townsend Project has made it
# Amy Macdonald has made it
# Stone Sour has made it
# The Feeling has made it
# Local Natives has made it
# Sia has made it
# Chelsea Wolfe has made it
# Psychostick has made it
# Buckcherry has made it
# Ivy Queen has made it
# Justin Bieber has made it
# Robbie Williams has made it
# Donald Fagen has made it
# Red Fang has made it
# Abandon All Ships has made it
# The War On Drugs has made it
# Serj Tankian has made it
# New Device has made it
# Lykke Li has made it
# Saint Vitus has made it
# Tinariwen has made it
# Emilie Autumn has made it
# Carrie Underwood has made it
# Lower Dens has made it
# Dragonette has made it
# Mumford & Sons has made it
# Atreyu has made it
# American Authors has made it
# Sarah Cracknell has made it
# Brian Wilson has made it
# Motion City Soundtrack has made it
# Harry Belafonte has made it
# Maximo Park has made it
# James Blunt has made it
# Ariel Pink's Haunted Graffiti has made it
# Hot Water Music has made it
# Plants and Animals has made it
# Nicole Scherzinger has made it
# Jack White has made it
# The Prodigy has made it
# Disclosure has made it
# Whitechapel has made it
# La Dispute has made it
# Andrew Jackson Jihad has made it
# Mind.in.a.box has made it
# Flyleaf has made it
# My Dying Bride has made it
# CHVRCHES has made it
# Kelly Clarkson has made it
# Mouse On Mars has made it
# Kenny Chesney has made it
# Eve 6 has made it
# Lone Ninja has made it
# Feeder has made it
# Lee Kernaghan has made it
# Brother Ali has made it
# The Darkness has made it
# Lana Del Rey has made it
# Nick Cave & The Bad Seeds has made it
# Kent has made it
# Bloc Party has made it
# In Fear And Faith has made it
# Darwin Deez has made it
# Red has made it
# Front Line Assembly has made it
# Boom Boom Satellites has made it
# The Bronx has made it
# Everclear has made it
# Hurts has made it
# Roxette has made it
# Mongo Santamaria has made it
# Kreayshawn has made it
# Gary Barlow has made it
# Zeromancer has made it
# Hopsin has made it
# Le Butcherettes has made it
# Breathe Carolina has made it
# Katy B has made it
# Raekwon has made it
# Travis has made it
# Rachele Lynae has made it
# Justice has made it
# The Winery Dogs has made it
# Panic! At The Disco has made it
# Within Temptation has made it
# We Are The Ocean has made it
# tobyMac has made it
# Soen has made it
# Goatwhore has made it
# The Mars Volta has made it
# Ra Ra Riot has made it
# Ulver has made it
# Lee Brice has made it
# Rufus Wainwright has made it
# Chunk! No, Captain Chunk! has made it
# Memoryhouse has made it
# Children Of Bodom has made it
# Scott Stapp has made it
# Sharron Levy has made it
# Raimundos has made it
# Johnny Clegg has made it
# The Big Pink has made it
# Melvins has made it
# Tove Lo has made it
# Tessanne Chin has made it
# Sufjan Stevens has made it
# Eve has made it
# Foo Fighters has made it
# Jimmy Cliff has made it
# Interpol has made it
# The Roots has made it
# Talib Kweli has made it
# Kid Down has made it
# Hoobastank has made it
# Epica has made it
# Selah Sue has made it
# Archive has made it
# Otep has made it
# Kiesza has made it
# Terje Isungset & Stian Westerhus has made it
# Courtney Barnett has made it
# Norah Jones has made it
# Alexandra Stan has made it
# Iron & Wine has made it
# Periphery has made it
# Nonpoint has made it
# Biffy Clyro has made it
# Ólafur Arnalds has made it
# Kimbra has made it
# Santigold has made it
# Mac Miller has made it
# Arve Henriksen has made it
# Kevin Max has made it
# Trapt has made it
# Leonard Cohen has made it
# Phillip Phillips has made it
# Dag Arnesen has made it
# Sigur Rós has made it
# Visage has made it
# The Veronicas has made it
# Selena Gomez has made it
# Jessica Sanchez has made it
# Slaughterhouse has made it
# Rihanna has made it
# Rick Ross has made it
# Wildlife Control has made it
# Steak Number Eight has made it
# Miss May I has made it
# The Offspring has made it
# Mary Lambert has made it
# Coal Chamber has made it
# Hinder has made it
# Jennifer Hudson has made it
# Joe McElderry has made it
# Riverbeds has made it
# múm has made it
# Infected Mushroom has made it
# R5 has made it
# Hiss Golden Messenger has made it
# Vince Staples has made it
# Janet Jackson has made it
# The Vaccines has made it
# Alestorm has made it
# Azealia Banks has made it
# Holly Herndon has made it
# At The Gates has made it
# Paper Aeroplanes has made it
# Justin Rutledge has made it
# The Black Ryder has made it
# Arctic Monkeys has made it
# Anthrax has made it
# Cher Lloyd has made it
# Cancer Bats has made it
# Lifehouse has made it
# Marilyn Manson has made it
# Sheppard has made it
# Big D and the Kids Table has made it
# Agalloch has made it
# Live has made it
# Sister Sparrow and the Dirty Birds has made it
# Yuna has made it
# Willie Nile has made it
# Kelis has made it
# Enter Shikari has made it
# John Cale has made it
# Yelawolf has made it
# Godspeed You! Black Emperor has made it
# Habib Koité has made it
# Stray From The Path has made it
# The Afghan Whigs has made it
# Grouplove has made it
# Marnie Stern has made it
# Karmin has made it
# Enrique Iglesias has made it
# Smosh has made it
# Beach House has made it
# The Defiled has made it
# Manu Dibango has made it
# Natalie Maines has made it
# The Ghost Inside has made it
# Kat Dahlia has made it
# Dir En Grey has made it
# The Chemical Brothers has made it
# Hozier has made it
# Robin Schulz has made it
# Elton John has made it
# Mark Owen has made it
# Pat Mastelotto has made it
# Parkway Drive has made it
# Richard Clayderman has made it
# The Babies has made it
# The Summer Set has made it
# The Little Willies has made it
# Amy Lee has made it
# blessthefall has made it
# Monte Pittman has made it
# Atmosphere has made it
# Sirens and Sailors has made it
# Boondox has made it
# Clean Bandit has made it
# Schoolboy Q has made it
# The Ting Tings has made it
# Ty Segall has made it
# Alice Russell has made it
# Blk Sonshine has made it
# Britney Spears has made it
# The Cat Empire has made it
# Kate Miller-Heidke has made it
# Keyshia Cole has made it
# Charli XCX has made it
# Stick To Your Guns has made it
# alt-J has made it
# Delain has made it
# FKA twigs has made it
# Rose Windows has made it
# Prince Royce has made it
# Danielle Bradbery has made it
# Noel Gallagher's High Flying Birds has made it
# My Bloody Valentine has made it
# Candice Glover has made it
# Dido has made it
# Cee Lo Green has made it
# Tiësto has made it
# All Time Low has made it
# Keane has made it
# Cynic has made it
# The Courteeners has made it
# Cher has made it
# Six Organs Of Admittance has made it
# Ashanti has made it
# Chance The Rapper has made it
# Adam Lambert has made it
# Kid Cudi has made it
# Nicki Minaj has made it
# Carly Rae Jepsen has made it
# Marc Anthony has made it
# Axel Rudi Pell has made it
# Diogal has made it
# Jowell & Randy has made it
# Francisca Valenzuela has made it
# Motörhead has made it
# Kishi Bashi has made it
# Sage Francis has made it
# Backstreet Boys has made it
# Take That has made it
# Moonspell has made it
# Melody's Echo Chamber has made it
# Voodoo Glow Skulls has made it
# Active Child has made it
# Powerman 5000 has made it
# Jessica Sutta has made it
# Sinéad O'Connor has made it
# Young Guns has made it
# Callisto has made it
# K-OS has made it
# Julieta Venegas has made it
# Santana has made it
# EMA has made it
# Nazareth has made it
# Rittz has made it
# Our Lady Peace has made it
# Sharon Van Etten has made it
# Adelitas Way has made it
# Of Montreal has made it
# Aaron Neville has made it
# The Presets has made it
# Shabazz Palaces has made it
# Sabrina Carpenter has made it
# Bombadil has made it
# John K. Samson has made it
# Public Service Broadcasting has made it
# The Toy Dolls has made it
# B.o.B has made it
# The Fray has made it
# Christina Aguilera has made it
# FOE has made it
# T.I. has made it
# Angie Stone has made it
# Machine Head has made it
# Anneke Van Giersbergen has made it
# Corrosion Of Conformity has made it
# Trailer Trash Tracys has made it
# Simple Minds has made it
# Jess Glynne has made it
# Wiz Khalifa has made it
# Fairweather has made it
# John Mayer has made it
# Mack Wilds has made it
# Umphrey's McGee has made it
# Ace Hood has made it
# Neurosis has made it
# Bruce Springsteen has made it
# Riverside has made it
# Wednesday 13 has made it
# Justin Townes Earle has made it
# Pierce The Veil has made it
# Betty Who has made it
# Big B feat. The Dirty Heads has made it
# Dead by April has made it
# Gallows has made it
# Katie Melua has made it
# Cold War Kids has made it
# Jungle has made it
# Killer Mike has made it
# The Dillinger Escape Plan has made it
# Our Last Night has made it
# Rae Sremmurd has made it
# Regina Spektor has made it
# Tesla has made it
# Converge has made it
# Gojira has made it
# Daniel Wesley has made it
# Baths has made it
# Foxy Shazam has made it
# Dream Theater has made it
# Van Halen has made it
# Guided By Voices has made it
# M.I has made it
# G-Unit has made it
# Maciré Sylla has made it
# Céline Dion has made it
# Cage The Elephant has made it
# Dr. Dre has made it
# Torche has made it
# Allison Moorer has made it
# Karen O has made it
# Tokyo Police Club has made it
# Comedian Bob Marley has made it
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-e7251e4d7990> in <module>()
#      28                     ec_trackId = ec_track['id']
#      29
# ---> 30                     audsum = ec_track['audio_summary']
#      31
#      32                     timesig = audsum['time_signature']
#
# KeyError: 'audio_summary'

# %%
z = pd.Series.from_csv('world-country-names.tsv', sep='\t')
set_countries = list(set([c for c in countries if c != 'United States']))
new_countries = []
new_ids = []
for c in set_countries:
    if c == 'South Korea':
        c = 'Korea, Republic of'
    if c == 'Russia':
        c = 'Russian Federation'
    if c in z.values:
        new_countries.append(c)
        new_ids.append(z[z==c].index[0])

pd.Series(new_countries, index=new_ids)

# %%
cur.execute('Select latitude, longitude from artists')
rows = cur.fetchall()
# import googlemapsapi as goog
# mapkey = goog.apikey()

def get_country(lat, lon):
    url = 'https://maps.googleapis.com/maps/api/geocode/json?latlng=%s,%s&key=%s' % (lat, lon, mapkey)
    obj = json.loads(requests.get(url).text)
    if obj['status'] == 'OK':
        result = obj['results'][0]
        components = result['address_components']
        country = [c['long_name'] for c in components if c['types'][0] == 'country'][0]
        return country
    else:
        return None

    
countries = []
for r in rows:
    lat = r[0]
    lon = r[1]
    countries.append(get_country(lat, lon))
set_countries = set([c for c in countries if c != 'United States'])
# Out:
# (51.5072648, -0.1278328)
# (51.5063, -0.12714)
# (51.5063, -0.12714)
# (33.76437, -116.339766)
# (33.401395, -111.931298)
# (33.7483, -84.3911)
# (40.7146, -74.0071)
# (53.0162014, -2.1812607)
# (50.8289, -0.13414)
# (2.04117, 45.3441)
# (59.3333333, 18.05)
# (35.2196, -80.0195)
# (51.5072648, -0.1278328)
# (51.505833, -3.577222)
# (33.973951, -118.248405)
# (38.8991, -77.029)
# (32.661269, -95.77607)
# (52.9533834, -1.1487384)
# (40.7146, -74.0071)
# (59.9123, 10.75)
# (60.391111, 5.324722)
# (33.9071, -118.012)
# (33.973951, -118.248405)
# (56.6661, 16.3637)
# (43.2848, -2.17764)
# (33.973951, -118.248405)
# (27.75, -18.0)
# (50.1213173, -5.5329266)
# (33.189011, -96.10887)
# (41.8842, -87.6324)
# (43.6486, -79.3853)
# (53.3418732, -1.2789459)
# (42.732535, -84.555535)
# (32.492683, -97.264359)
# (53.7974185, -1.5437941)
# (29.7605, -95.3698)
# (43.3262, -79.7985)
# (-38.3843, 142.483)
# (41.5524, -81.4645)
# (-37.7984, 144.979)
# (64.1101, -21.8929)
# (40.694481, -73.989319)
# (35.187133, -117.885359)
# (33.7483, -84.3911)
# (41.850033, -87.650052)
# (45.507856, -122.690794)
# (25.779808, -80.1532)
# (36.1678, -86.7784)
# (33.787874, -117.852006)
# (35.187133, -117.885359)
# (34.5819444, -95.9980556)
# (51.7562, -1.25949)
# (51.5072648, -0.1278328)
# (58.9708, 5.73079)
# (35.187133, -117.885359)
# (36.165688, -86.778098)
# (33.844371, -84.47405)
# (58.1438, 7.99484)
# (30.1426, -94.6421)
# (33.660297, -117.999227)
# (51.8251, -3.02055)
# (34.0535, -118.245)
# (42.370567, -71.026964)
# (40.736101, -74.22509)
# (53.7289, -1.87821)
# (47.60621, -122.332071)
# (45.4689, 9.18103)
# (18.4662, -66.1067)
# (40.7909, -73.9664)
# (51.3339, 6.5623)
# (64.15, -21.95)
# (31.2436111, -90.4530556)
# (35.6705, 139.741)
# (60.0, -95.0)
# (33.608922, -91.207356)
# (40.6551, -73.9489)
# (-35.3065, 149.127)
# (51.5063, -0.12714)
# (51.1869, 10.0531)
# (33.844371, -84.47405)
# (40.219809, -79.49533)
# (35.9605, -83.9209)
# (38.5791, -121.491)
# (38.5791, -121.491)
# (52.9533834, -1.1487384)
# (33.787874, -117.852006)
# (42.8854, -78.8785)
# (36.165688, -86.778098)
# (51.5013012, -0.117287)
# (54.0, -2.0)
# (36.1063, -79.6599)
# (48.8569, 2.3412)
# (54.1768, -6.34067)
# (51.5072648, -0.1278328)
# (38.895112, -77.036366)
# (40.7146, -74.0071)
# (60.2, 12.0)
# (48.433333, -123.35)
# (38.5791, -121.491)
# (41.8842, -87.6324)
# (30.326374, -97.771258)
# (27.996097, -82.582035)
# (54.0, -2.0)
# (39.1328, -76.69253)
# (40.311353, -111.72496)
# (40.5064, -74.2657)
# (-41.0, 174.0)
# (40.77185, -74.207039)
# (33.973951, -118.248405)
# (33.993396, -118.465193)
# (32.781179, -96.790329)
# (41.88, -87.7789)
# (12.653, -7.98648)
# (33.973951, -118.248405)
# (60.1755556, 24.9341667)
# (40.960347, -74.125036)
# (40.714269, -74.005973)
# (29.7605, -95.3698)
# (62.0, 10.0)
# (51.5072648, -0.1278328)
# (40.155927, -76.464018)
# (40.6786, -73.589)
# (44.25, -76.95)
# (42.96502, -86.176715)
# (35.79652, -81.43065)
# (48.4, -4.483333)
# (54.9911912, -1.5342042)
# (37.2719, -119.27)
# (40.47441, -79.950968)
# (41.88, -87.7789)
# (10.9406, -74.7797)
# (34.032383, -119.1343)
# (51.75, -1.25)
# (51.45, -2.583333)
# (62.1, 30.15)
# (32.5851, -89.8737)
# (47.432251, -121.803388)
# (53.4098, -2.97848)
# (50.8288134, -0.1473061)
# (50.8288134, -0.1473061)
# (47.60621, -122.332071)
# (51.5072648, -0.1278328)
# (53.5, -2.216667)
# (41.8842, -87.6324)
# (41.0905556, -73.9183333)
# (53.4796, -2.24881)
# (55.7522222, 37.6155556)
# (37.768, -78.2057)
# (34.0535, -118.245)
# (39.15017, -123.20778)
# (59.3333333, 18.05)
# (51.84, -0.2751)
# (40.001811, -75.11787)
# (43.666667, -79.416667)
# (40.714269, -74.005973)
# (33.870292, -117.925338)
# (51.7562, -1.25949)
# (44.65, -63.6)
# (-33.9191, 18.422)
# (35.7855, -78.6427)
# (34.0535, -118.245)
# (36.301068, -115.206969)
# (33.973951, -118.248405)
# (42.3586, -71.0567)
# (58.7366, 5.64433)
# (35.631914, -81.17193)
# (45.5118, -122.676)
# (51.5072648, -0.1278328)
# (53.7974185, -1.5437941)
# (49.2604, -123.114)
# (41.4101, -75.6608)
# (18.25, -66.5)
# (34.541371, -84.024387)
# (45.5118, -122.676)
# (42.170731, -72.604842)
# (51.5072648, -0.1278328)
# (48.866667, 2.333333)
# (52.638, -1.14043)
# (33.844371, -84.47405)
# (40.702898, -74.010241)
# (53.4, -2.15)
# (51.5063, -0.12714)
# (42.347021, -83.060184)
# (33.973951, -118.248405)
# (40.8077778, -73.9458333)
# (53.5, -2.216667)
# (43.3504, -84.5603)
# (51.5072648, -0.1278328)
# (44.3, -78.333333)
# (33.973951, -118.248405)
# (39.952335, -75.163789)
# (53.3438, -6.24953)
# (31.106, -97.6475)
# (44.6462, -63.5739)
# (39.208888, -76.562926)
# (45.5118, -122.676)
# (40.2886, -76.6509)
# (53.9885, -7.36215)
# (39.139336, -77.182953)
# (-36.866667, 174.766667)
# (33.7879, -117.85)
# (42.8333, 12.8333)
# (39.279656, -94.982216)
# (32.724103, -117.170912)
# (37.6366667, 127.2141667)
# (33.660297, -117.999227)
# (39.962545, -80.719815)
# (51.5072648, -0.1278328)
# (53.3418732, -1.2789459)
# (42.984226, -85.629101)
# (37.0429, 22.1115)
# (51.5063, -0.12714)
# (33.973951, -118.248405)
# (40.7146, -74.0071)
# (27.9465, -82.4593)
# (13.0, -2.0)
# (40.714269, -74.005973)
# (51.666667, -0.4)
# (32.625298, -90.008601)
# (28.5382, -81.3774)
# (-34.933333, 138.6)
# (33.471773, -86.800823)
# (40.714269, -74.005973)
# (40.714269, -74.005973)
# (57.7166667, 11.9666667)
# (51.4356, -2.57518)
# (49.2604, -123.114)
# (45.5, -73.583333)
# (27.8333, -81.717)
# (51.3477845, -0.8606505)
# (42.300596, -71.27875)
# (-25.7069444, 28.2294444)
# (40.486754, -74.444395)
# (-37.8175, 144.967)
# (37.553758, -77.460262)
# (33.9182, -118.354)
# (55.9483399, -3.1932723)
# (42.474786, -82.995121)
# (33.4483333, -112.0733333)
# (37.7796, -122.42)
# (40.914289, -73.33268)
# (34.0535, -118.245)
# (39.952335, -75.163789)
# (51.4524, -0.99603)
# (47.6036, -122.329)
# (60.7313, 14.9974)
# (40.7146, -74.0071)
# (42.8854, -78.8785)
# (-34.9261, 138.6)
# (37.5407, -77.4336)
# (47.432251, -121.803388)
# (37.5663889, 126.9997222)
# (44.979, -93.2649)
# (62.0, 10.0)
# (33.7879, -117.85)
# (44.9438, -63.5357)
# (52.023, 8.53326)
# (41.486689, -73.491042)
# (59.3322, 18.0624)
# (-31.933333, 115.833333)
# (29.7605, -95.3698)
# (45.5118, -122.676)
# (51.5072648, -0.1278328)
# (43.2638, -79.9524)
# (32.8117, 34.9987)
# (33.973951, -118.248405)
# (40.756095, -111.900719)
# (53.9533, -1.08342)
# (53.4098, -2.97848)
# (51.7993232, 0.6433317)
# (37.786027, -122.223779)
# (51.5072648, -0.1278328)
# (39.166759, -84.53822)
# (41.8842, -87.6324)
# (37.5663889, 126.9997222)
# (45.7594, 4.82898)
# (33.874815, -118.240208)
# (40.694481, -73.989319)
# (30.2676, -97.743)
# (40.7146, -74.0071)
# (33.973951, -118.248405)
# (36.039147, -95.868667)
# (40.7563, -73.9376)
# (51.5072648, -0.1278328)
# (48.7523, -122.471)
# (-32.05, 115.766667)
# (18.25, -66.5)
# (38.244889, -122.135862)
# (51.4537, -2.59156)
# (33.5203, 132.853)
# (-33.8696, 151.207)
# (52.4813678, -1.8980725)
# (40.4948, -74.4438)
# (58.2225, 26.4211111)
# (33.9816, -117.374)
# (34.0535, -118.245)
# (41.774725, -73.401908)
# (33.808161, -84.170196)
# (51.5072648, -0.1278328)
# (33.973951, -118.248405)
# (40.714269, -74.005973)
# (32.372144, -85.66671)
# (39.7591, -84.1944)
# (33.864, -118.395)
# (47.9166667, 13.8)
# (51.1642, 10.4542)
# (53.783333, -1.75)
# (53.4796, -2.24881)
# (32.737933, -97.24507)
# (53.7945, -1.54658)
# (57.7013, 11.9669)
# (33.5438, -84.2277)
# (-40.9493, 175.657)
# (40.594597, -105.127416)
# (44.8017, -68.7708)
# (-37.816667, 144.966667)
# (40.8572, -73.8568)
# (41.850033, -87.650052)
# (55.6666667, 12.5833333)
# (52.8029, -2.10633)
# (35.187133, -117.885359)
# (34.0535, -118.245)
# (41.5047, -81.6907)
# (49.2604, -123.114)
# (42.3586, -71.0567)
# (-33.9191, 18.422)
# (33.9875, -118.472)
# (28.545179, -81.373291)
# (36.165688, -86.778098)
# (42.89606, -78.886424)
# (40.6551, -73.9489)
# (30.2676, -97.743)
# (36.0308, -114.981)
# (33.844371, -84.47405)
# (56.25, -3.166667)
# (56.6722, 12.8575)
# (32.9546, -117.042)
# (56.65, 10.0)
# (-33.883333, 151.216667)
# (-36.866667, 174.766667)
# (44.979, -93.2649)
# (44.979, -93.2649)
# (43.25, -79.833333)
# (54.0, -2.0)
# (-34.933333, 138.6)
# (51.0, 9.0)
# (40.7146, -74.0071)
# (39.962998, -76.727139)
# (53.3831, -1.46454)
# (33.4483, -112.076)
# (59.3333333, 18.05)
# (33.973951, -118.248405)
# (53.7289, -1.87821)
# (39.1822, -77.27)
# (28.5382, -81.3774)
# (34.0535, -118.245)
# (51.585278, -3.326944)
# (40.358409, -74.068143)
# (40.714269, -74.005973)
# (33.973951, -118.248405)
# (-37.816667, 144.966667)
# (51.083333, -114.083333)
# (50.7583, -1.54859)
# (34.937085, -79.649111)
# (37.7796, -122.42)
# (48.8569, 2.3412)
# (35.1497, -90.0489)
# (60.0, -95.0)
# (51.5118, -0.20594)
# (37.5571, 126.977)
# (51.84, -0.2751)
# (40.5581, 8.31862)
# (37.235551, -77.335396)
# (41.85, -87.65)
# (43.666667, -79.416667)
# (40.6551, -73.9489)
# (42.265275, -71.879415)
# (51.45, -2.583333)
# (30.326374, -97.771258)
# (55.8578, -4.24251)
# (33.7483, -84.3911)
# (50.1121, 8.68341)
# (36.1719, -115.14)
# (40.723713, -73.950971)
# (51.5063, -0.12714)
# (49.3843, -84.7563)
# (51.749, -0.47508)
# (32.758408, -96.301323)
# (56.0694599, -3.4604559)
# (33.973951, -118.248405)
# (49.2064, -122.91)
# (55.9044088, -4.226358)
# (41.5898, -93.6157)
# (51.0676687, -0.3270352)
# (34.0535, -118.245)
# (-34.933333, 138.6)
# (34.0535, -118.245)
# (33.401395, -111.931298)
# (34.0535, -118.245)
# (40.714269, -74.005973)
# (43.366667, -80.983333)
# (53.0297, -2.17507)
# (40.855103, -74.126916)
# (45.507856, -122.690794)
# (43.6486, -79.3853)
# (40.001811, -75.11787)
# (33.973951, -118.248405)
# (54.3141, -2.23001)
# (59.3333333, 18.05)
# (33.973951, -118.248405)
# (17.0, -4.0)
# (33.973951, -118.248405)
# (35.47, -95.5224)
# (39.2906, -76.6096)
# (43.666667, -79.416667)
# (51.5072648, -0.1278328)
# (33.7879, -117.85)
# (42.370567, -71.026964)
# (51.7357, 0.47791)
# (33.914775, -118.348083)
# (44.984577, -93.269097)
# (40.8084, -73.9469)
# (54.988056, -1.619444)
# (51.2377, -1.67012)
# (33.973951, -118.248405)
# (29.652, -82.3232)
# (45.5, -73.583333)
# (33.973951, -118.248405)
# (42.347021, -83.060184)
# (51.8790108, 0.5501584)
# (51.2316107, -0.3756192)
# (35.9605, -83.9209)
# (42.9967, -85.5901)
# (33.4483333, -112.0733333)
# (48.2, 16.3666667)
# (30.983551, -97.521848)
# (53.783333, -1.75)
# (55.861147, -4.2499891)
# (32.492683, -97.264359)
# (50.9417, 6.95518)
# (36.15369, -83.78241)
# (34.212114, -118.239978)
# (40.7146, -74.0071)
# (51.5911, -2.9883)
# (-19.9327, 145.774)
# (44.979, -93.2649)
# (52.4726, 1.72548)
# (44.2821, -73.9827)
# (-37.816667, 144.966667)
# (59.3723, 16.5165)
# (51.5063, -0.12714)
# (32.7157, -117.162)
# (40.7146, -74.0071)
# (36.165688, -86.778098)
# (49.25, -123.133333)
# (37.4876, 139.838)
# (34.0535, -118.245)
# (45.5118, -122.676)
# (53.5, -2.216667)
# (56.6722, 12.8575)
# (23.0833, -82.4167)
# (37.8051, -122.273)
# (53.4796, -2.24881)
# (64.5565, 12.6662)
# (34.0535, -118.245)
# (20.6876, -103.351)
# (39.74, -104.992)
# (51.5072648, -0.1278328)
# (40.5725, -74.154)
# (55.861147, -4.2499891)
# (36.165688, -86.778098)
# (48.866667, 2.333333)
# (40.694481, -73.989319)
# (36.1719, -115.14)
# (52.0446, 4.65507)
# (51.6465, 0.06581)
# (38.8461111, -77.3066667)
# (-26.7147, 27.098)
# (29.9537, -90.0777)
# (31.7592, -106.487)
# (43.05, -76.1474)
# (59.9123, 10.75)
# (33.913678, -80.354238)
# (45.5, -73.583333)
# (48.8569, 2.3412)
# (43.666667, -79.416667)
# (60.2068, 24.6558)
# (35.386, -77.9968)
# (47.8, 13.0333333)
# (-15.7785, -47.9287)
# (-26.2, 28.0833333)
# (51.5063, -0.12714)
# (46.9838, -123.601)
# (59.3333333, 18.05)
# (18.0, -76.8)
# (42.347021, -83.060184)
# (40.001811, -75.11787)
# (47.6036, -122.329)
# (18.4333, -77.7833)
# (42.1497, -74.9384)
# (40.001811, -75.11787)
# (40.6551, -73.9489)
# (59.0526, 12.7048)
# (34.1458, -118.778)
# (51.2833333, 6.0833333)
# (50.8794, 4.70367)
# (51.5072648, -0.1278328)
# (34.0535, -118.245)
# (51.0452, -114.063)
# (64.5565, 12.6662)
# (-37.816667, 144.966667)
# (33.220974, -97.146038)
# (44.1833333, 28.65)
# (33.987454, -81.024864)
# (38.9864, -77.0969)
# (26.1237, -80.1436)
# (55.6092, -4.50015)
# (64.9639, -19.0212)
# (-37.783333, 175.283333)
# (40.001811, -75.11787)
# (40.47441, -79.950968)
# (62.3078, 6.92775)
# (42.984226, -85.629101)
# (37.2212, -121.979)
# (45.5, -73.583333)
# (31.560674, -84.176751)
# (62.0, 10.0)
# (64.15, -21.95)
# (54.3141, -2.23001)
# (-27.4689, 153.023)
# (34.1016, -118.337)
# (32.7157, -117.162)
# (42.3317, -83.0479)
# (13.1667, -59.5333)
# (25.941, -80.2462)
# (40.694481, -73.989319)
# (50.808, 3.17992)
# (40.0399, -84.2039)
# (33.6789, -118.002)
# (47.60621, -122.332071)
# (34.0535, -118.245)
# (35.472, -97.5203)
# (41.8842, -87.6324)
# (54.9994168, -1.4309132)
# (46.8, -71.25)
# (64.9639, -19.0212)
# (32.8155556, 34.9891667)
# (33.973951, -118.248405)
# (35.850295, -79.023205)
# (35.187133, -117.885359)
# (41.590686, -87.319937)
# (51.5072648, -0.1278328)
# (56.3994, -3.44252)
# (40.714269, -74.005973)
# (35.737569, -87.473903)
# (57.7013, 11.9669)
# (51.7169, -5.02691)
# (43.6486, -79.3853)
# (-33.8696, 151.207)
# (53.3831, -1.46454)
# (40.7146, -74.0071)
# (52.1115443, -2.3268573)
# (43.666667, -79.416667)
# (33.973951, -118.248405)
# (40.782408, -81.371185)
# (-27.0, 133.0)
# (42.352374, -71.135112)
# (45.5118, -122.676)
# (39.9068, -76.6586)
# (40.694481, -73.989319)
# (2.5, 112.5)
# (42.8854, -78.8785)
# (40.714269, -74.005973)
# (51.7536, -0.3373)
# (51.8011, -3.89752)
# (34.0148, -86.0072)
# (45.5123, -73.5544)
# (12.65, -8.0)
# (40.8525, -73.1358)
# (39.166759, -84.53822)
# (33.973951, -118.248405)
# (40.7146, -74.0071)
# (42.370567, -71.026964)
# (25.779808, -80.1532)
# (38.380456, -121.555406)
# (39.2906, -76.6096)
# (35.6705, 139.741)
# (7.36529, 12.3434)
# (33.5777778, -101.8547222)
# (33.973951, -118.248405)
# (25.790654, -80.130046)
# (34.6666667, 135.5)
# (53.4796, -2.24881)
# (53.2027778, -6.0983333)
# (51.0, 9.0)
# (51.5968712, -0.3770142)
# (53.5403, -2.11232)
# (39.732, -121.842)
# (-28.65, 153.616667)
# (48.866667, 2.333333)
# (40.694481, -73.989319)
# (33.494, -111.921)
# (40.714269, -74.005973)
# (34.9513, -92.3809)
# (33.4483, -112.076)
# (32.5006, -94.7411)
# (44.979, -93.2649)
# (43.286024, -77.684264)
# (33.5968, -83.8616)
# (52.2033051, 0.124862)
# (34.0535, -118.245)
# (53.4897, -2.2843)
# (37.7796, -122.42)
# (50.8289, -0.13414)
# (-28.4793, 24.6799)
# (30.814466, -90.428043)
# (-37.816667, 144.966667)
# (-27.5, 153.016667)
# (33.973951, -118.248405)
# (51.5072648, -0.1278328)
# (33.787874, -117.852006)
# (53.7974185, -1.5437941)
# (52.5126, 6.08873)
# (54.0, -2.0)
# (47.60621, -122.332071)
# (40.714269, -74.005973)
# (29.83399, -95.434241)
# (53.4796, -2.24881)
# (53.3438, -6.24953)
# (33.92198, -80.360323)
# (51.5063, -0.12714)
# (33.844371, -84.47405)
# (51.5666667, 4.8)
# (39.407156, -76.60379)
# (50.9155, 0.48883)
# (25.729, -80.2374)
# (53.4796, -2.24881)
# (33.973951, -118.248405)
# (37.2719, -119.27)
# (40.714269, -74.005973)
# (41.850033, -87.650052)
# (32.7157, -117.162)
# (40.694481, -73.989319)
# (40.714269, -74.005973)
# (49.133333, -122.3)
# (40.714269, -74.005973)
# (51.1642, 10.4542)
# (14.4994, -14.4455)
# (18.2233, -66.4289)
# (37.7796, -122.42)
# (51.5063, -0.12714)
# (47.6036, -122.329)
# (41.82275, -71.414451)
# (28.545179, -81.373291)
# (53.5, -2.216667)
# (39.5579, -7.84481)
# (48.866667, 2.333333)
# (33.9816, -117.374)
# (33.973951, -118.248405)
# (42.3586, -71.0567)
# (25.729, -80.2374)
# (53.3330556, -6.2488889)
# (51.6294, -0.74739)
# (60.45, 22.2833333)
# (43.666667, -79.416667)
# (32.533333, -117.016667)
# (37.784827, -122.727802)
# (44.2853, -99.4632)
# (56.0694599, -3.4604559)
# (33.9608, -84.0379)
# (43.6486, -79.3853)
# (40.6551, -73.9489)
# (36.1719, -115.14)
# (33.9581, -83.3733)
# (29.9537, -90.0777)
# (-33.8696, 151.207)
# (47.60621, -122.332071)
# (40.9947, -77.6045)
# (35.9953, -78.896)
# (49.8994, -97.1408)
# (51.5072648, -0.1278328)
# (54.9001, -1.40848)
# (33.772554, -84.291723)
# (39.743291, -105.069027)
# (40.623632, -74.093323)
# (51.5063, -0.12714)
# (33.844371, -84.47405)
# (33.9986, -81.0452)
# (37.8051, -122.273)
# (51.7681, 5.52616)
# (35.7855, -78.6427)
# (51.5063, -0.12714)
# (55.8578, -4.24251)
# (51.5909437, -0.141941)
# (40.4383, -79.9975)
# (38.0033, -79.7713)
# (41.308873, -73.363661)
# (40.623632, -74.093323)
# (41.8842, -87.6324)
# (26.311102, -80.09787)
# (37.8051, -122.273)
# (40.2345, -74.295)
# (52.2354, 21.0094)
# (35.8262, -80.2507)
# (40.7146, -74.0071)
# (32.724103, -117.170912)
# (-33.883333, 151.216667)
# (36.1719, -115.14)
# (57.7013, 11.9669)
# (51.666667, -0.4)
# (51.5072648, -0.1278328)
# (33.803448, -118.168135)
# (51.5072648, -0.1278328)
# (33.7483, -84.3911)
# (40.82177, -74.48099)
# (42.74314, -71.59174)
# (33.844371, -84.47405)
# (40.7146, -74.0071)
# (38.5791, -121.491)
# (42.5224, -70.8958)
# (43.483333, -1.483333)
# (49.0239, -122.797)
# (33.973951, -118.248405)
# (39.166759, -84.53822)
# (42.3586, -71.0567)
# (33.786594, -118.298662)
# (39.7591, -84.1944)
# (42.2448, -84.4005)
# (40.7038, -73.8317)
# (9.93488, -9.66063)
# (45.7215, -73.4867)
# (36.9946, -86.4456)
# (34.0535, -118.245)
# (25.729, -80.2374)
# (30.6864, -88.0532)
# (40.1432, -74.7267)
# (44.05, -79.45)
# (45.2623, -69.0125)

# %%
# import numpy as np
cur.execute('Select * from audiosummary')
audsum = cur.fetchall()
audiomatrix = list(audsum[0][1:])

for i in range(len(audsum)):
    if any(iter(a is None for a in audsum[i])) == False:
        audiomatrix = np.c_[audiomatrix, list(audsum[i][1:])]
    else:
        print i

audiomatrix = audiomatrix.T[1:]
# Out:
# 676
# 684

# %%
from sklearn.cluster import KMeans
# clusters = KMeans.fit_predict(k = 10,audiomatrix)
model = KMeans(n_clusters=24).fit(audiomatrix)
labels = model.labels_

values = model.cluster_centers_

# %%
countries_order = countries[0:676]+countries[677:684]+countries[685:]

# %%
def cluster_number(n):
    cluster = []
    for i in range(len(labels)):
        if labels[i] == n:
            cluster.append(countries_order[i])
    return cluster

# %%
for i in range(24):
    print len(cluster_number(i))
# Out:
# 32
# 50
# 30
# 54
# 43
# 33
# 55
# 31
# 9
# 19
# 47
# 38
# 20
# 27
# 2
# 23
# 29
# 33
# 26
# 36
# 48
# 7
# 34
# 10

# %%
cur.execute('Select genres from artists')
genres = cur.fetchall()
genres_order = genres[0:676]+genres[677:684]+genres[685:]

# %%
def cluster_names(n):
    cluster = []
    for i in range(len(labels)):
        if labels[i] == n:
            tup = (artists_order[i], genres[i], countries_order[i])
            cluster.append(tup)
    return cluster

# %%
cluster_names(3)
# Out:
# [(('Jukebox The Ghost',), ([],), u'United States'),
#  (('Burzum',), (['black metal', 'pagan black metal'],), u'Norway'),
#  (('Sons Of Magdalene',), ([],), u'United States'),
#  (('Sirenia',),
#   (['gothic metal', 'gothic symphonic metal', 'symphonic metal'],),
#   u'Norway'),
#  (('The Band Perry',), ([],), u'United States'),
#  (('The Birthday Massacre',), ([],), u'Canada'),
#  (('Ashley Monroe',), (['country dawn'],), u'United States'),
#  (('LP',), ([],), u'United States'),
#  (('Hildegunn \xc3\x98iseth',), ([],), u'Norway'),
#  (("Jamie's Elsewhere",), (['screamo'],), u'United States'),
#  (('Oceans Ate Alaska',), ([],), u'United Kingdom'),
#  (('Dionne Warwick',), ([],), u'United States'),
#  (('Mayer Hawthorne',), ([],), u'United States'),
#  (('Suicidal Tendencies',), (['crossover thrash'],), u'United States'),
#  (('Anti-Flag',),
#   (['melodic hardcore', 'punk', 'skate punk'],),
#   u'United States'),
#  (('The Neighbourhood',), (['shimmer pop'],), u'United States'),
#  (('French Montana',), ([],), u'United States'),
#  (('The Dandy Warhols',),
#   (['indie christmas', 'neo-psychedelic'],),
#   u'United States'),
#  (('Emblem3',), ([],), u'United States'),
#  (('Sonny Landreth',), (['modern blues'],), u'United States'),
#  (('I See Stars',), ([],), u'United States'),
#  (('WALK THE MOON',), (['shimmer pop'],), u'United States'),
#  (('Jean-Michel Jarre',), ([],), u'France'),
#  (('Death Cab for Cutie',), ([],), u'United States'),
#  (('The Courteeners',), (['british indie rock'],), u'United Kingdom'),
#  (('Bobby Womack',),
#   (['soul', 'soul christmas', 'southern soul'],),
#   u'United States'),
#  (('Brandon Flowers',), ([],), u'United States'),
#  (('Northlane',), (['deep melodic metalcore'],), u'Australia'),
#  (('Lacrimosa',), ([],), u'Germany'),
#  (('Ian Anderson',),
#   (['progressive rock', 'symphonic rock'],),
#   u'United Kingdom'),
#  (('Mumford & Sons',), (['folk-pop'],), u'United Kingdom'),
#  (('Brian Wilson',), ([],), u'United States'),
#  (('Whitechapel',), (['death core'],), u'United States'),
#  (('Justice',), (['filter house'],), u'France'),
#  (('tobyMac',),
#   (['ccm',
#     'christian alternative rock',
#     'christian music',
#     'christian rock'],),
#   u'United States'),
#  (('Goatwhore',), ([],), u'United States'),
#  (('Chunk! No, Captain Chunk!',), ([],), u'France'),
#  (('Tessanne Chin',), ([],), u'Jamaica'),
#  (('Kid Down',), ([],), u'Sweden'),
#  (('Selah Sue',), ([],), u'Belgium'),
#  (('Leonard Cohen',),
#   (['folk', 'singer-songwriter', 'traditional folk'],),
#   u'Canada'),
#  (('Visage',), ([],), u'United Kingdom'),
#  (('Steak Number Eight',), ([],), u'Belgium'),
#  (('At The Gates',),
#   (['death metal', 'melodic death metal', 'swedish metal'],),
#   u'Sweden'),
#  (('Big D and the Kids Table',), (['ska', 'ska punk'],), u'United States'),
#  (('The Afghan Whigs',), (['alternative rock'],), u'United States'),
#  (('Grouplove',), ([],), u'United States'),
#  (('Alice Russell',), ([],), u'United Kingdom'),
#  (('Ti\xc3\xabsto',),
#   (['big room',
#     'deep progressive trance',
#     'deep uplifting trance',
#     'edm',
#     'electro house',
#     'house',
#     'progressive electro house',
#     'progressive house',
#     'progressive trance',
#     'trance',
#     'uplifting trance'],),
#   u'Netherlands'),
#  (('Santana',), ([],), u'United States'),
#  (('Simple Minds',), (['stoner rock'],), u'United Kingdom'),
#  (('Justin Townes Earle',), ([],), u'United States'),
#  (('Pierce The Veil',), (['horror punk'],), u'United States'),
#  (('Macir\xc3\xa9 Sylla',), (['afrobeats'],), u'Guinea')]

# %%
ages = [98,34,12]
addresses = ['main','finderne','rocky']
ppl = ['jamie', 'rodger', 'camila']

# %%
dic = {}
for i in range(len(ppl)):
    name = ppl[i]
    age = ages[i]
    add = addresses[i]
    agedict = {"age", age}
    adddict = {"add", add}
    dic[name]=(agedict,adddict)
